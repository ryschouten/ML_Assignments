# %% [markdown]
# # MNIST Classification with TensorFlow (Fully Connected Network and CNN)
#
# This notebook implements **two neural networks** using TensorFlow/Keras for the MNIST digit classification task:
#
# 1. A **fully connected (dense) neural network** with architecture `784 → 512 → 512 → 10` using ReLU activations and a final Softmax.
# 2. A **convolutional neural network (CNN)** following the block structure:
#    `Input → Convolution → Max Pooling → Convolution → Dropout → Max Pooling → Convolution → Max Pooling → Linear → Linear → Output`
#
# For **each network** we will:
#
# - Load and preprocess the MNIST data.
# - Define the model architecture in TensorFlow.
# - Specify the **loss function**, **optimizer**, and **metrics**.
# - Implement an explicit **training loop** using `tf.GradientTape`.
# - Track **training and validation loss and accuracy per epoch** and plot them.
# - Run a **prediction example** on a test image and visualize both the image and the predicted probabilities.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Make sure we're using TensorFlow 2.x in eager mode
print("TensorFlow version:", tf.__version__)

# ===============================
# 1. Load and preprocess MNIST
# ===============================

# MNIST has 60,000 training and 10,000 test images of size 28x28 (grayscale).
# Keras will automatically download it the first time you call this.
(x_train_full, y_train_full), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

print("Original training set shape:", x_train_full.shape, y_train_full.shape)
print("Original test set shape:", x_test.shape, y_test.shape)

# -------------------------------------------------
# Normalize images to [0, 1] by dividing by 255.0
# -------------------------------------------------
x_train_full = x_train_full.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# ---------------------------------------
# Create a validation split from training
# ---------------------------------------
# We'll use 50,000 images for training and 10,000 for validation.
x_train, x_val = x_train_full[:50000], x_train_full[50000:]
y_train, y_val = y_train_full[:50000], y_train_full[50000:]

print("Training set:", x_train.shape, y_train.shape)
print("Validation set:", x_val.shape, y_val.shape)
print("Test set:", x_test.shape, y_test.shape)

# ==============================================
# Prepare data for the fully connected network
# ==============================================

# Flatten images to vectors of length 784 = 28*28
x_train_flat = x_train.reshape(-1, 28 * 28)
x_val_flat = x_val.reshape(-1, 28 * 28)
x_test_flat = x_test.reshape(-1, 28 * 28)

print("Flattened training set shape:", x_train_flat.shape)

# ==============================================
# Prepare data for the CNN
# ==============================================

# Add a channel dimension to each image so the shape is (28, 28, 1)
x_train_cnn = x_train[..., tf.newaxis]
x_val_cnn = x_val[..., tf.newaxis]
x_test_cnn = x_test[..., tf.newaxis]

print("CNN training data shape:", x_train_cnn.shape)

# ==============================================
# Build tf.data.Datasets for efficient iteration
# ==============================================

batch_size = 128

# Datasets for fully connected network
train_ds_fc = tf.data.Dataset.from_tensor_slices((x_train_flat, y_train)).shuffle(10000).batch(batch_size)
val_ds_fc   = tf.data.Dataset.from_tensor_slices((x_val_flat, y_val)).batch(batch_size)
test_ds_fc  = tf.data.Dataset.from_tensor_slices((x_test_flat, y_test)).batch(batch_size)

# Datasets for CNN
train_ds_cnn = tf.data.Dataset.from_tensor_slices((x_train_cnn, y_train)).shuffle(10000).batch(batch_size)
val_ds_cnn   = tf.data.Dataset.from_tensor_slices((x_val_cnn, y_val)).batch(batch_size)
test_ds_cnn  = tf.data.Dataset.from_tensor_slices((x_test_cnn, y_test)).batch(batch_size)

# ==============================================
# Shared helper: accuracy computation
# ==============================================

def accuracy_from_probs(probs, labels):
    # Compute accuracy from predicted probabilities and true labels.
    preds = tf.argmax(probs, axis=1, output_type=tf.int32)
    labels = tf.cast(labels, tf.int32)
    correct = tf.equal(preds, labels)
    return tf.reduce_mean(tf.cast(correct, tf.float32))
# Out:
# TensorFlow version: 2.19.0
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Original training set shape: (60000, 28, 28) (60000,)
# Original test set shape: (10000, 28, 28) (10000,)
# Training set: (50000, 28, 28) (50000,)
# Validation set: (10000, 28, 28) (10000,)
# Test set: (10000, 28, 28) (10000,)
# Flattened training set shape: (50000, 784)
# CNN training data shape: (50000, 28, 28, 1)

# %%
# ===============================================
# 2. Fully Connected Network definition
#    Architecture: 784 -> 512 -> 512 -> 10
# ===============================================

fc_model = tf.keras.Sequential(
    [
        # Input: vectors of length 784
        tf.keras.layers.Input(shape=(784,), name="input_flattened"),

        # First hidden dense layer with 512 units and ReLU activation
        tf.keras.layers.Dense(512, activation="relu", name="dense_1"),

        # Second hidden dense layer with 512 units and ReLU activation
        tf.keras.layers.Dense(512, activation="relu", name="dense_2"),

        # Output layer with 10 units (one per digit class) and Softmax
        # Softmax converts logits to a probability distribution over classes.
        tf.keras.layers.Dense(10, activation="softmax", name="output_softmax"),
    ],
    name="FullyConnectedMNIST",
)

fc_model.summary()

# Loss function: SparseCategoricalCrossentropy (integer labels 0-9)
loss_fn_fc = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)

# Optimizer: Adam
optimizer_fc = tf.keras.optimizers.Adam(learning_rate=1e-3)

# Metric histories
fc_train_loss_history = []
fc_val_loss_history = []
fc_train_acc_history = []
fc_val_acc_history = []

# Number of epochs for training the FC network
epochs_fc = 10
# Out:
# Model: "FullyConnectedMNIST"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_softmax (Dense)          │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 669,706 (2.55 MB)
#  Trainable params: 669,706 (2.55 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# ===============================================
# 3. Training + validation loop for FC network
# ===============================================

for epoch in range(1, epochs_fc + 1):
    print(f"\n=== [FC Network] Epoch {epoch}/{epochs_fc} ===")

    # ---------- Training phase ----------
    train_losses = []
    train_accuracies = []

    for step, (x_batch, y_batch) in enumerate(train_ds_fc):
        with tf.GradientTape() as tape:
            # Forward pass
            probs = fc_model(x_batch, training=True)
            # Compute loss
            loss_value = loss_fn_fc(y_batch, probs)

        # Compute gradients and update weights
        grads = tape.gradient(loss_value, fc_model.trainable_variables)
        optimizer_fc.apply_gradients(zip(grads, fc_model.trainable_variables))

        # Compute accuracy
        acc = accuracy_from_probs(probs, y_batch)

        train_losses.append(loss_value.numpy())
        train_accuracies.append(acc.numpy())

        if step % 100 == 0:
            print(f"  Step {step:03d} - Batch loss: {loss_value:.4f}, accuracy: {acc:.4f}")

    # Aggregate training metrics
    epoch_train_loss = np.mean(train_losses)
    epoch_train_acc = np.mean(train_accuracies)

    # ---------- Validation phase ----------
    val_losses = []
    val_accuracies = []

    for x_batch_val, y_batch_val in val_ds_fc:
        probs_val = fc_model(x_batch_val, training=False)
        val_loss_value = loss_fn_fc(y_batch_val, probs_val)
        val_acc = accuracy_from_probs(probs_val, y_batch_val)

        val_losses.append(val_loss_value.numpy())
        val_accuracies.append(val_acc.numpy())

    epoch_val_loss = np.mean(val_losses)
    epoch_val_acc = np.mean(val_accuracies)

    # Store history
    fc_train_loss_history.append(epoch_train_loss)
    fc_val_loss_history.append(epoch_val_loss)
    fc_train_acc_history.append(epoch_train_acc)
    fc_val_acc_history.append(epoch_val_acc)

    print(
        f"Epoch {epoch}: "
        f"Train loss = {epoch_train_loss:.4f}, Train acc = {epoch_train_acc:.4f} | "
        f"Val loss = {epoch_val_loss:.4f}, Val acc = {epoch_val_acc:.4f}"
    )
# Out:
# === [FC Network] Epoch 1/10 ===
#   Step 000 - Batch loss: 2.3493, accuracy: 0.1016
#   Step 100 - Batch loss: 0.2500, accuracy: 0.9141
#   Step 200 - Batch loss: 0.1832, accuracy: 0.9609
#   Step 300 - Batch loss: 0.1888, accuracy: 0.9375
# Epoch 1: Train loss = 0.2397, Train acc = 0.9297 | Val loss = 0.1055, Val acc = 0.9685
#
# === [FC Network] Epoch 2/10 ===
#   Step 000 - Batch loss: 0.1262, accuracy: 0.9844
#   Step 100 - Batch loss: 0.0782, accuracy: 0.9609
#   Step 200 - Batch loss: 0.1066, accuracy: 0.9688
#   Step 300 - Batch loss: 0.1406, accuracy: 0.9531
# Epoch 2: Train loss = 0.0864, Train acc = 0.9735 | Val loss = 0.0873, Val acc = 0.9727
#
# === [FC Network] Epoch 3/10 ===
#   Step 000 - Batch loss: 0.1697, accuracy: 0.9609
#   Step 100 - Batch loss: 0.1059, accuracy: 0.9688
#   Step 200 - Batch loss: 0.1071, accuracy: 0.9844
#   Step 300 - Batch loss: 0.1328, accuracy: 0.9766
# Epoch 3: Train loss = 0.0531, Train acc = 0.9838 | Val loss = 0.0812, Val acc = 0.9753
#
# === [FC Network] Epoch 4/10 ===
#   Step 000 - Batch loss: 0.0646, accuracy: 0.9766
#   Step 100 - Batch loss: 0.0296, accuracy: 0.9922
#   Step 200 - Batch loss: 0.0293, accuracy: 0.9844
#   Step 300 - Batch loss: 0.0743, accuracy: 0.9609
# Epoch 4: Train loss = 0.0381, Train acc = 0.9878 | Val loss = 0.0874, Val acc = 0.9751
#
# === [FC Network] Epoch 5/10 ===
#   Step 000 - Batch loss: 0.0466, accuracy: 0.9922
#   Step 100 - Batch loss: 0.0106, accuracy: 0.9922
#   Step 200 - Batch loss: 0.0043, accuracy: 1.0000
#   Step 300 - Batch loss: 0.0780, accuracy: 0.9609
# Epoch 5: Train loss = 0.0266, Train acc = 0.9915 | Val loss = 0.0784, Val acc = 0.9777
#
# === [FC Network] Epoch 6/10 ===
#   Step 000 - Batch loss: 0.0324, accuracy: 0.9844
#   Step 100 - Batch loss: 0.0118, accuracy: 1.0000
#   Step 200 - Batch loss: 0.0171, accuracy: 1.0000
#   Step 300 - Batch loss: 0.0589, accuracy: 0.9844
# Epoch 6: Train loss = 0.0241, Train acc = 0.9917 | Val loss = 0.0928, Val acc = 0.9754
#
# === [FC Network] Epoch 7/10 ===
#   Step 000 - Batch loss: 0.0085, accuracy: 1.0000
#   Step 100 - Batch loss: 0.0089, accuracy: 0.9922
#   Step 200 - Batch loss: 0.0255, accuracy: 0.9922
#   Step 300 - Batch loss: 0.0124, accuracy: 1.0000
# Epoch 7: Train loss = 0.0200, Train acc = 0.9932 | Val loss = 0.0955, Val acc = 0.9770
#
# === [FC Network] Epoch 8/10 ===
#   Step 000 - Batch loss: 0.0188, accuracy: 0.9922
#   Step 100 - Batch loss: 0.0322, accuracy: 0.9844
#   Step 200 - Batch loss: 0.0010, accuracy: 1.0000
#   Step 300 - Batch loss: 0.0140, accuracy: 0.9922
# Epoch 8: Train loss = 0.0160, Train acc = 0.9943 | Val loss = 0.0986, Val acc = 0.9767
#
# === [FC Network] Epoch 9/10 ===
#   Step 000 - Batch loss: 0.0031, accuracy: 1.0000
#   Step 100 - Batch loss: 0.0013, accuracy: 1.0000
#   Step 200 - Batch loss: 0.0037, accuracy: 1.0000
#   Step 300 - Batch loss: 0.0031, accuracy: 1.0000
# Epoch 9: Train loss = 0.0138, Train acc = 0.9954 | Val loss = 0.0799, Val acc = 0.9818
#
# === [FC Network] Epoch 10/10 ===
#   Step 000 - Batch loss: 0.0108, accuracy: 0.9922
#   Step 100 - Batch loss: 0.0023, accuracy: 1.0000
#   Step 200 - Batch loss: 0.0010, accuracy: 1.0000
#   Step 300 - Batch loss: 0.0283, accuracy: 0.9922
# Epoch 10: Train loss = 0.0096, Train acc = 0.9970 | Val loss = 0.1105, Val acc = 0.9766

# %%
# ===============================================
# 4. Plot FC training/validation curves and show example prediction
# ===============================================

epochs_range_fc = range(1, epochs_fc + 1)

plt.figure()
plt.plot(epochs_range_fc, fc_train_loss_history, label="Train Loss")
plt.plot(epochs_range_fc, fc_val_loss_history, label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Fully Connected Network - Loss per Epoch")
plt.legend()
plt.grid(True)
plt.show()

plt.figure()
plt.plot(epochs_range_fc, fc_train_acc_history, label="Train Accuracy")
plt.plot(epochs_range_fc, fc_val_acc_history, label="Val Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Fully Connected Network - Accuracy per Epoch")
plt.legend()
plt.grid(True)
plt.show()

# Example prediction from the FC network
sample_index = 0
sample_image_flat = x_test_flat[sample_index : sample_index + 1]  # shape (1, 784)
sample_image = x_test[sample_index]  # shape (28, 28)
true_label = y_test[sample_index]

probs = fc_model(sample_image_flat, training=False).numpy().squeeze()
predicted_class = np.argmax(probs)

print("True label:", true_label)
print("Predicted class (FC network):", predicted_class)
print("Predicted probabilities:", probs)

plt.figure()
plt.imshow(sample_image, cmap="gray")
plt.title(f"FC Network Prediction: {predicted_class} (True: {true_label})")
plt.axis("off")
plt.show()
# Out:
# True label: 7
# Predicted class (FC network): 7
# Predicted probabilities: [2.6108315e-12 9.5849204e-11 9.5819776e-11 1.6126314e-11 3.3751044e-16
#  2.8761795e-12 6.3203084e-17 1.0000000e+00 4.6657268e-14 2.3854840e-11]

# %%
# ===============================================
# 5. CNN model definition
#    Architecture outline:
#    Input -> Conv -> MaxPool -> Conv -> Dropout
#          -> MaxPool -> Conv -> MaxPool -> Dense -> Dense -> Output
# ===============================================

cnn_model = tf.keras.Sequential(
    [
        tf.keras.layers.Input(shape=(28, 28, 1), name="input_image"),

        # Block 1: Conv -> MaxPool
        tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation="relu", name="conv_1"),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2), name="maxpool_1"),

        # Block 2: Conv -> Dropout -> MaxPool
        tf.keras.layers.Conv2D(64, kernel_size=(3, 3), activation="relu", name="conv_2"),
        tf.keras.layers.Dropout(0.25, name="dropout_1"),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2), name="maxpool_2"),

        # Block 3: Conv -> MaxPool
        tf.keras.layers.Conv2D(128, kernel_size=(3, 3), activation="relu", name="conv_3"),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2), name="maxpool_3"),

        # Flatten and two fully connected layers
        tf.keras.layers.Flatten(name="flatten"),
        tf.keras.layers.Dense(128, activation="relu", name="dense_1"),
        tf.keras.layers.Dense(64, activation="relu", name="dense_2"),

        # Output layer with Softmax over 10 classes
        tf.keras.layers.Dense(10, activation="softmax", name="output_softmax"),
    ],
    name="CNN_MNIST",
)

cnn_model.summary()

# Loss function and optimizer (same form as FC network)
loss_fn_cnn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
optimizer_cnn = tf.keras.optimizers.Adam(learning_rate=1e-3)

# Metric histories
cnn_train_loss_history = []
cnn_val_loss_history = []
cnn_train_acc_history = []
cnn_val_acc_history = []

epochs_cnn = 10
# Out:
# Model: "CNN_MNIST"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv_1 (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ maxpool_1 (MaxPooling2D)        │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_2 (Conv2D)                 │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 11, 11, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ maxpool_2 (MaxPooling2D)        │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_3 (Conv2D)                 │ (None, 3, 3, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ maxpool_3 (MaxPooling2D)        │ (None, 1, 1, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_softmax (Dense)          │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 118,090 (461.29 KB)
#  Trainable params: 118,090 (461.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# ===============================================
# 6. Training + validation loop for CNN
# ===============================================

for epoch in range(1, epochs_cnn + 1):
    print(f"\n=== [CNN] Epoch {epoch}/{epochs_cnn} ===")

    # ---------- Training phase ----------
    train_losses = []
    train_accuracies = []

    for step, (x_batch, y_batch) in enumerate(train_ds_cnn):
        with tf.GradientTape() as tape:
            probs = cnn_model(x_batch, training=True)
            loss_value = loss_fn_cnn(y_batch, probs)

        grads = tape.gradient(loss_value, cnn_model.trainable_variables)
        optimizer_cnn.apply_gradients(zip(grads, cnn_model.trainable_variables))

        acc = accuracy_from_probs(probs, y_batch)

        train_losses.append(loss_value.numpy())
        train_accuracies.append(acc.numpy())

        if step % 100 == 0:
            print(f"  Step {step:03d} - Batch loss: {loss_value:.4f}, accuracy: {acc:.4f}")

    epoch_train_loss = np.mean(train_losses)
    epoch_train_acc = np.mean(train_accuracies)

    # ---------- Validation phase ----------
    val_losses = []
    val_accuracies = []
    for x_batch_val, y_batch_val in val_ds_cnn:
        probs_val = cnn_model(x_batch_val, training=False)
        val_loss_value = loss_fn_cnn(y_batch_val, probs_val)
        val_acc = accuracy_from_probs(probs_val, y_batch_val)

        val_losses.append(val_loss_value.numpy())
        val_accuracies.append(val_acc.numpy())

    epoch_val_loss = np.mean(val_losses)
    epoch_val_acc = np.mean(val_accuracies)

    cnn_train_loss_history.append(epoch_train_loss)
    cnn_val_loss_history.append(epoch_val_loss)
    cnn_train_acc_history.append(epoch_train_acc)
    cnn_val_acc_history.append(epoch_val_acc)

    print(
        f"Epoch {epoch}: "
        f"Train loss = {epoch_train_loss:.4f}, Train acc = {epoch_train_acc:.4f} | "
        f"Val loss = {epoch_val_loss:.4f}, Val acc = {epoch_val_acc:.4f}"
    )
# Out:
# === [CNN] Epoch 1/10 ===
#   Step 000 - Batch loss: 2.3004, accuracy: 0.1016
#   Step 100 - Batch loss: 0.2130, accuracy: 0.9453
#   Step 200 - Batch loss: 0.1068, accuracy: 0.9688
#   Step 300 - Batch loss: 0.1700, accuracy: 0.9531
# Epoch 1: Train loss = 0.3460, Train acc = 0.8962 | Val loss = 0.1270, Val acc = 0.9628
#
# === [CNN] Epoch 2/10 ===
#   Step 000 - Batch loss: 0.1515, accuracy: 0.9453
#   Step 100 - Batch loss: 0.1338, accuracy: 0.9453
#   Step 200 - Batch loss: 0.1121, accuracy: 0.9531
#   Step 300 - Batch loss: 0.0506, accuracy: 0.9844
# Epoch 2: Train loss = 0.1063, Train acc = 0.9673 | Val loss = 0.0838, Val acc = 0.9768
#
# === [CNN] Epoch 3/10 ===
#   Step 000 - Batch loss: 0.0586, accuracy: 0.9922
#   Step 100 - Batch loss: 0.0543, accuracy: 0.9922
#   Step 200 - Batch loss: 0.0147, accuracy: 1.0000
#   Step 300 - Batch loss: 0.1340, accuracy: 0.9609
# Epoch 3: Train loss = 0.0763, Train acc = 0.9762 | Val loss = 0.0682, Val acc = 0.9794
#
# === [CNN] Epoch 4/10 ===
#   Step 000 - Batch loss: 0.0210, accuracy: 1.0000
#   Step 100 - Batch loss: 0.0818, accuracy: 0.9766
#   Step 200 - Batch loss: 0.0369, accuracy: 0.9844
#   Step 300 - Batch loss: 0.0189, accuracy: 0.9922
# Epoch 4: Train loss = 0.0593, Train acc = 0.9814 | Val loss = 0.0565, Val acc = 0.9835
#
# === [CNN] Epoch 5/10 ===
#   Step 000 - Batch loss: 0.1731, accuracy: 0.9453
#   Step 100 - Batch loss: 0.0186, accuracy: 0.9922
#   Step 200 - Batch loss: 0.0227, accuracy: 0.9922
#   Step 300 - Batch loss: 0.0280, accuracy: 0.9922
# Epoch 5: Train loss = 0.0519, Train acc = 0.9837 | Val loss = 0.0584, Val acc = 0.9832
#
# === [CNN] Epoch 6/10 ===
#   Step 000 - Batch loss: 0.0050, accuracy: 1.0000
#   Step 100 - Batch loss: 0.0670, accuracy: 0.9688
#   Step 200 - Batch loss: 0.0212, accuracy: 1.0000
#   Step 300 - Batch loss: 0.0281, accuracy: 0.9922
# Epoch 6: Train loss = 0.0433, Train acc = 0.9856 | Val loss = 0.0569, Val acc = 0.9831
#
# === [CNN] Epoch 7/10 ===
#   Step 000 - Batch loss: 0.0295, accuracy: 0.9922
#   Step 100 - Batch loss: 0.0341, accuracy: 0.9844
#   Step 200 - Batch loss: 0.0299, accuracy: 0.9922
#   Step 300 - Batch loss: 0.0143, accuracy: 0.9922
# Epoch 7: Train loss = 0.0392, Train acc = 0.9877 | Val loss = 0.0499, Val acc = 0.9866
#
# === [CNN] Epoch 8/10 ===
#   Step 000 - Batch loss: 0.0452, accuracy: 0.9922
#   Step 100 - Batch loss: 0.0047, accuracy: 1.0000
#   Step 200 - Batch loss: 0.0728, accuracy: 0.9922
#   Step 300 - Batch loss: 0.0079, accuracy: 1.0000
# Epoch 8: Train loss = 0.0334, Train acc = 0.9891 | Val loss = 0.0482, Val acc = 0.9860
#
# === [CNN] Epoch 9/10 ===
#   Step 000 - Batch loss: 0.0345, accuracy: 0.9922
#   Step 100 - Batch loss: 0.0335, accuracy: 0.9844
#   Step 200 - Batch loss: 0.0142, accuracy: 1.0000
#   Step 300 - Batch loss: 0.0467, accuracy: 0.9844
# Epoch 9: Train loss = 0.0298, Train acc = 0.9901 | Val loss = 0.0383, Val acc = 0.9873
#
# === [CNN] Epoch 10/10 ===
#   Step 000 - Batch loss: 0.0646, accuracy: 0.9844
#   Step 100 - Batch loss: 0.0293, accuracy: 0.9922
#   Step 200 - Batch loss: 0.0154, accuracy: 1.0000
#   Step 300 - Batch loss: 0.0014, accuracy: 1.0000
# Epoch 10: Train loss = 0.0275, Train acc = 0.9913 | Val loss = 0.0377, Val acc = 0.9892

# %%
# ===============================================
# 7. Plot CNN training/validation curves and show example prediction
# ===============================================

epochs_range_cnn = range(1, epochs_cnn + 1)

plt.figure()
plt.plot(epochs_range_cnn, cnn_train_loss_history, label="Train Loss")
plt.plot(epochs_range_cnn, cnn_val_loss_history, label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("CNN - Loss per Epoch")
plt.legend()
plt.grid(True)
plt.show()

plt.figure()
plt.plot(epochs_range_cnn, cnn_train_acc_history, label="Train Accuracy")
plt.plot(epochs_range_cnn, cnn_val_acc_history, label="Val Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("CNN - Accuracy per Epoch")
plt.legend()
plt.grid(True)
plt.show()

# Example prediction from the CNN
sample_index = 1  # different from FC example

sample_image_cnn = x_test_cnn[sample_index : sample_index + 1]  # shape (1, 28, 28, 1)
sample_image_raw = x_test[sample_index]  # shape (28, 28)
true_label_cnn = y_test[sample_index]

probs_cnn = cnn_model(sample_image_cnn, training=False).numpy().squeeze()
predicted_class_cnn = np.argmax(probs_cnn)

print("True label:", true_label_cnn)
print("Predicted class (CNN):", predicted_class_cnn)
print("Predicted probabilities:", probs_cnn)

plt.figure()
plt.imshow(sample_image_raw, cmap="gray")
plt.title(f"CNN Prediction: {predicted_class_cnn} (True: {true_label_cnn})")
plt.axis("off")
plt.show()
# Out:
# True label: 2
# Predicted class (CNN): 2
# Predicted probabilities: [1.0238514e-05 4.8485786e-06 9.9996853e-01 1.0668242e-05 2.5820063e-07
#  1.9147379e-08 4.7923149e-06 2.7935695e-07 9.0476220e-08 2.5852833e-07]
